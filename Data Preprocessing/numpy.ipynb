# %%
import numpy as np
import time

# %%
size = 10_000_000
 
py_list = list(range(size))
start = time.time()
sq_list = [x**2 for x in py_list]
end = time.time()
print(f"python List time = {end-start} seconds")

np_arr = np.array(py_list)
start = time.time()
sq_array= np_arr**2
end = time.time()
print(f"python array time = {end-start} seconds")
# Out:
# python List time = 0.5491576194763184 seconds
# python array time = 0.02060389518737793 seconds
