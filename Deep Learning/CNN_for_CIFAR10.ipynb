# %%
import torch 
import torch.nn as nn
import torch.optim as optim 

import torchvision 
from torchvision.datasets import CIFAR10

# %%
# Datasets & DataLoaders
from torch.utils.data import DataLoader
import torchvision.transforms as transforms

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset = CIFAR10(root="C:/Users/mayan/OneDrive/Desktop/Mayank(HP)/programs/Learning_AIML/Cleaned_data/Image_Classification_dataset", train=True, download=True, transform=transform)
testset = CIFAR10(root="C:/Users/mayan/OneDrive/Desktop/Mayank(HP)/programs/Learning_AIML/Cleaned_data/Image_Classification_dataset", train=False, download=True, transform=transform)

# %%
trainloader = DataLoader(trainset, batch_size=64, shuffle=True)
testloader = DataLoader(testset, batch_size=64)

# %% [markdown]
# ### Build the CNN

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN , self).__init__()

        self.conv_layers = nn.Sequential(
            # 1st Convolutional layer
            nn.Conv2d(3,32, kernel_size = 3,padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),# kernal size = 2, stride = 2

            # 2nd Convolutional layer
            nn.Conv2d(32,64, kernel_size = 3,padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),# kernal size = 2, stride = 2

            # 3rd Convolutional layer
            nn.Conv2d(64,128, kernel_size = 3,padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2)# kernal size = 2, stride = 2 
        )


        self.fc_layers = nn.Sequential(
            nn.Linear(4*4*128 , 256),
            nn.ReLU(),

            nn.Linear(256,10)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(x.size(0), -1) # flattening
        x = self.fc_layers(x)

        return x

# %%
model = CNN()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %% [markdown]
# # Training the CNN

# %%
epochs = 10

for epoch in range(epochs):
    epoch_training_loss = 0.0

    for images, labels in trainloader:
        optimizer.zero_grad()
        
        output = model.forward(images) # FP
        loss = criterion(output, labels) # loss fnx
        loss.backward() # BP
        optimizer.step() # update params

        epoch_training_loss += loss.item()

    print(f"epoch={epoch+1}/{epochs} & loss={epoch_training_loss/len(trainloader)}")
# Out:
# epoch=1/10 & loss=1.3673335856488904
# epoch=2/10 & loss=0.9447675635442709
# epoch=3/10 & loss=0.7537001456750934
# epoch=4/10 & loss=0.631530169597672
# epoch=5/10 & loss=0.5255381559090846
# epoch=6/10 & loss=0.43518900981796976
# epoch=7/10 & loss=0.35421654219974946
# epoch=8/10 & loss=0.27536620477886153
# epoch=9/10 & loss=0.21121808049052268
# epoch=10/10 & loss=0.16778695552855197

# %%
# Evaludate our CNN

correct_labels = 0
total_labels = 0

model.eval()

with torch.no_grad():
    for images, labels in testloader:
        outputs = model.forward(images)
        _, predicted  = torch.max(outputs, 1)

        correct_labels += (predicted == labels).sum().item()
        total_labels += labels.size(0)

print(f"accuracy = {correct_labels / total_labels * 100}")
# Out:
# accuracy = 75.05
